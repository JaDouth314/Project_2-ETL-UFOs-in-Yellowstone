# %% [markdown]
# # Project 2: UFO Sightings in Wyoming and Yellowstone National Park Visitation
#
# ## Group 4: Armand Dauti, Jacob Douthett, and Sam Espe

# %% [markdown]
# ### Overview
#
# INSERT OVERVIEW HERE

# %%
# Import dependencies

import pandas as pd
from sqlalchemy import create_engine, inspect
from datetime import datetime

# %% [markdown]
# ### Extract

# %%
# Extract data into dataframes

ufo_file = "Resources/ufo_data_scrubbed.csv"
ufo_df = pd.read_csv(ufo_file)

ufo_df.head()
# Out:
# C:\Users\itssm\AppData\Local\Temp\ipykernel_18768\911020618.py:4: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo_df = pd.read_csv(ufo_file)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#    longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
yellowstone_file = "Resources/Yellostone_Annual_Park_Recreation_Visitation_1904-2018.csv"
yellowstone_df = pd.read_csv(yellowstone_file)

yellowstone_df.head()
# Out:
#    year recreationvisitors totalrecreationvisitors
# 0  1904             13,727             183,271,650
# 1  1905             26,188             183,271,650
# 2  1906             17,182             183,271,650
# 3  1907             16,414             183,271,650
# 4  1908             19,542             183,271,650

# %% [markdown]
# ### Transform

# %% [markdown]
# #### Transform UFO data

# %%
# Drop entries that have NaN values

ufo_no_nan_states = ufo_df.dropna(axis=0, how='any')

ufo_no_nan_states.head()
# Out:
#            datetime        city state country     shape duration (seconds)  \
# 0  10/10/1949 20:30  san marcos    tx      us  cylinder               2700
# 3  10/10/1956 21:00        edna    tx      us    circle                 20
# 4  10/10/1960 20:00     kaneohe    hi      us     light                900
# 5  10/10/1961 19:00     bristol    tn      us    sphere                300
# 7  10/10/1965 23:45     norwalk    ct      us      disk               1200
#
#   duration (hours/min)                                           comments  \
# 0           45 minutes  This event took place in early fall around 194...
# 3             1/2 hour  My older brother and twin sister were leaving ...
# 4           15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5            5 minutes  My father is now 89 my brother 52 the girl wit...
# 7           20 minutes  A bright orange color changing to reddish colo...
#
#   date posted    latitude  longitude
# 0   4/27/2004  29.8830556  -97.941111
# 3   1/17/2004  28.9783333  -96.645833
# 4   1/22/2004  21.4180556 -157.803611
# 5   4/27/2007  36.5950000  -82.188889
# 7   10/2/1999  41.1175000  -73.408333

# %%
# Filter UFO dataframe to include only entries from Wyoming

ufos_wyoming_df = ufo_no_nan_states[ufo_no_nan_states["state"].str.contains("wy")]

ufos_wyoming_df.head()
# Out:
#               datetime       city state country     shape duration (seconds)  \
# 881    10/1/2008 20:00   glenrock    wy      us   unknown               1200
# 1340  10/13/2006 20:30    rawlins    wy      us  triangle                 30
# 2021  10/15/2001 03:00  chugwater    wy      us     light                 30
# 2057  10/15/2002 18:00     bosler    wy      us   unknown                120
# 2207  10/15/2010 02:30   cheyenne    wy      us     light                900
#
#      duration (hours/min)                                           comments  \
# 881         several hours  Stationary object just above NE horizon with f...
# 1340               30 sec  I was sitting in my hot tub looking at the sky...
# 2021           30 seconds                  F.E. Warren AFB Wyoming sightings
# 2057            2 minutes  Women pass through Bosler&#44 Wyoming twice wi...
# 2207           15 minutes                      U.F.O in Cheyenne&#44 Wyoming
#
#      date posted    latitude  longitude
# 881   10/31/2008  42.8613889 -105.871667
# 1340  10/30/2006  41.7911111 -107.238056
# 2021    9/9/2003  41.7566667 -104.821111
# 2057  10/31/2003  41.5761111 -105.694722
# 2207  11/21/2010  41.1400000 -104.819722

# %%
# Dropping index #6496 because the datetime object is invalid

ufos_wyoming_df = ufos_wyoming_df.drop(index=6496)

ufos_wyoming_df.head(50)
# Out:
#                datetime                   city state country      shape  \
# 881     10/1/2008 20:00               glenrock    wy      us    unknown
# 1340   10/13/2006 20:30                rawlins    wy      us   triangle
# 2021   10/15/2001 03:00              chugwater    wy      us      light
# 2057   10/15/2002 18:00                 bosler    wy      us    unknown
# 2207   10/15/2010 02:30               cheyenne    wy      us      light
# 2593   10/17/2008 19:20  colony (1 mile nw of)    wy      us    unknown
# 3527   10/21/2011 19:30          hulett (near)    wy      us      light
# 4197   10/23/2013 21:15                 alcova    wy      us      light
# 4239   10/24/2001 23:00               evanston    wy      us       oval
# 4545   10/25/2008 21:00           rock springs    wy      us      other
# 5034   10/28/2001 21:00                laramie    wy      us   fireball
# 5050   10/28/2004 02:00               sheridan    wy      us      light
# 5976   10/31/2011 20:15           rock springs    wy      us     sphere
# 6075    10/3/2003 20:51                  clark    wy      us      light
# 6247    10/4/1999 17:25               gillette    wy      us      other
# 6427    10/5/1997 19:00               cheyenne    wy      us      other
# 6599    10/5/2013 12:15                  clark    wy      us    unknown
# 6669    10/6/2002 19:25                 lander    wy      us     circle
# 6934    10/7/2008 20:00                  lyman    wy      us      flash
# 8262    1/11/2001 21:50                 dubois    wy      us   fireball
# 8309    11/1/2003 00:00               cheyenne    wy      us   fireball
# 8645   11/12/1998 02:25                 casper    wy      us   triangle
# 9222   11/14/2011 18:50            green river    wy      us   triangle
# 9453   11/15/2001 21:10                  clark    wy      us      light
# 12511  11/23/1999 22:30                 casper    wy      us     sphere
# 13400  11/28/2002 18:30               cheyenne    wy      us   fireball
# 14450   11/4/2007 00:40                 powell    wy      us   triangle
# 14899   11/5/2005 23:28                laramie    wy      us      light
# 15068   11/5/2011 21:30             torrington    wy      us      cigar
# 15528   1/17/1989 20:00                laramie    wy      us      other
# 15696   11/7/2006 21:00                laramie    wy      us  rectangle
# 15793   1/17/2011 20:00                 casper    wy      us     sphere
# 15821   11/7/2012 19:30                 casper    wy      us     sphere
# 15843   11/7/2013 01:45                 casper    wy      us    chevron
# 16323   1/19/1989 20:15                laramie    wy      us       disk
# 17220  12/11/2013 18:25                 powell    wy      us    chevron
# 17711  12/12/2005 23:00               evanston    wy      us     sphere
# 17969  12/13/2010 18:24               gillette    wy      us   fireball
# 18422  12/15/2011 17:30                laramie    wy      us   changing
# 18719  12/17/2010 18:15                buffalo    wy      us       disk
# 18977  12/19/2006 21:00               sheridan    wy      us      light
# 22158   1/23/2014 23:00          fort washakie    wy      us      light
# 22608   12/5/2005 21:00               cheyenne    wy      us    unknown
# 23337   12/7/2012 06:30           rock springs    wy      us       disk
# 23370   12/7/2013 01:00                laramie    wy      us     sphere
# 23978   12/9/2013 18:30                buffalo    wy      us      light
# 24143   1/31/1999 19:30               riverton    wy      us   fireball
# 25205    1/8/2001 18:30               gillette    wy      us   changing
# 25224    1/8/2003 20:15           rock springs    wy      us      light
# 26419   2/14/2004 22:25                 casper    wy      us   triangle
#
#       duration (seconds) duration (hours/min)  \
# 881                 1200        several hours
# 1340                  30               30 sec
# 2021                  30           30 seconds
# 2057                 120            2 minutes
# 2207                 900           15 minutes
# 2593                 300          5 minutes +
# 3527                  12     10 to 12 seconds
# 4197                   7            7 seconds
# 4239               18000               5hours
# 4545                 120              1-2 min
# 5034                  35                35sec
# 5050                  90           90 seconds
# 5976                 120            2 minutes
# 6075                 300            5 minutes
# 6247                  15           10-15 sec.
# 6427                  90              1.5 min
# 6599                 120            2 minutes
# 6669                   1                1 sec
# 6934                 600           10 minutes
# 8262                 1.5              1.5 sec
# 8309                   5            5 seconds
# 8645                 180          2-3 minutes
# 9222                  15               15 sec
# 9453                 600           10 minutes
# 12511                 60             1 minute
# 13400                  5            5 seconds
# 14450                 10           10 seconds
# 14899                  2          1-2 seconds
# 15068                  2        a few seconds
# 15528                900           15 minutes
# 15696                  5          3-5 seconds
# 15793              21600              6 hours
# 15821                 20        15-20 seconds
# 15843                  3          2-3 seconds
# 16323                600           10 minutes
# 17220                 10          ~10 seconds
# 17711                240        several hours
# 17969                 10           10 seconds
# 18422                900     15 minutes aprox
# 18719                  3            3 seconds
# 18977                300       multiple hours
# 22158               3600               1 hour
# 22608                  5            5 seconds
# 23337                120           ~2 minutes
# 23370               1800           30 minutes
# 23978               1800           30 minutes
# 24143                  5            5 seconds
# 25205               5400       18:30 to 22:00
# 25224               3600               1 hour
# 26419                600           10 minutes
#
#                                                 comments date posted  \
# 881    Stationary object just above NE horizon with f...  10/31/2008
# 1340   I was sitting in my hot tub looking at the sky...  10/30/2006
# 2021                   F.E. Warren AFB Wyoming sightings    9/9/2003
# 2057   Women pass through Bosler&#44 Wyoming twice wi...  10/31/2003
# 2207                       U.F.O in Cheyenne&#44 Wyoming  11/21/2010
# 2593               Uknown object over northeast Wyoming.  10/31/2008
# 3527   Bright silver object with silver trail traveli...  10/25/2011
# 4197   A mysterious shooting star heads straight for ...  11/11/2013
# 4239   observed a oblong green glassy object starting...  11/20/2001
# 4545   10 bird like shapes in straight line. glowed o...   1/10/2009
# 5034   I saw a bright very bright light apear in the ...  11/20/2001
# 5050   Object flying over the tree line at the Big Ho...   1/19/2005
# 5976   One white star like light over Rock Springs Wy...  12/12/2011
# 6075   Clark&#44 WY. object or Light heading S.W. at ...   11/8/2003
# 6247   At 5:20 P.M. my wife and I were taken our 10 y...  10/19/1999
# 6427   Seen a object in clear sky.looked like commet ...   1/11/2002
# 6599   6 Invisible objects con trails only.  ((NUFORC...  10/14/2013
# 6669   a green circular light appeared and then darte...  10/15/2002
# 6934   Red/Silver flashing light going across the sky...  10/31/2008
# 8262                      Bright &#44 fast falling light   2/18/2001
# 8309            A huge fireball east of Cheyenne Wyoming   1/17/2004
# 8645   back oObserved a boomerang shaped object trave...    4/1/2000
# 9222   I was in my back yard and loooked up  and saw ...  12/12/2011
# 9453   I have been seeing a bright light for years in...  11/20/2001
# 12511  My wife and I witnessed a craft hovering over ...  12/16/1999
# 13400  Fireball seen in night sky near Cheyenne WY Th...  12/23/2002
# 14450  single triangle craft with four dim light ring...  11/28/2007
# 14899  I saw a white light flash out of my drivers wi...   11/8/2005
# 15068  I was on a hill enjoying the sunset. I fell as...  12/12/2011
# 15528  Silent lighted craft flies over house&#44 witn...  10/31/2003
# 15696  Fast moving&#44 silent&#44 black rectangle see...    8/7/2007
# 15793  Multiple&#44 white&#44 sphericle craft pretend...   1/31/2011
# 15821  Saw a green orb floating/flying object above m...  11/19/2012
# 15843                           Unexplained over Casper.  11/11/2013
# 16323  Witness is lured out of house&#44 silent craft...  10/31/2003
# 17220                     Bright flashes in north sky...  12/12/2013
# 17711  multicolored lights hover and fly  over evanst...   2/14/2006
# 17969  Large White/Green Object Descends over Gillett...    1/5/2011
# 18422              Large Orange UFO over Laramie&#44 WY.  12/17/2011
# 18719  Black dinner plate size crab like object that ...    1/5/2011
# 18977  Bright light in southeastern sky emitting red&...    2/1/2007
# 22158  Observed a still standing white silver red lig...   1/30/2014
# 22608  An orange object viewed intermmitantly in the ...   2/14/2006
# 23337  Male witness reports seeing a red disc&#44 see...  12/20/2012
# 23370  Bright orange sphere sitting in same spot for ...   1/10/2014
# 23978  Re-occurring for last month hovering light wit...  12/12/2013
# 24143  We were driving westbound on Hwy between River...   1/29/2002
# 25205                           Bright light follows me.   2/18/2001
# 25224  It was like an airport becon that was rotating...   3/21/2003
# 26419  4 triangular orange and red lighted in casper&...    3/2/2004
#
#          latitude  longitude
# 881    42.8613889 -105.871667
# 1340   41.7911111 -107.238056
# 2021   41.7566667 -104.821111
# 2057   41.5761111 -105.694722
# 2207   41.1400000 -104.819722
# 2593   44.8700000 -104.154722
# 3527   44.6827778 -104.601111
# 4197   42.5522222 -106.715833
# 4239   41.2683333 -110.962500
# 4545   41.5875000 -109.202222
# 5034   41.3113889 -105.590556
# 5050   44.7972222 -106.955556
# 5976   41.5875000 -109.202222
# 6075   44.8994444 -109.150278
# 6247   44.2911111 -105.501667
# 6427   41.1400000 -104.819722
# 6599   44.8994444 -109.150278
# 6669   42.8330556 -108.730000
# 6934   41.3275000 -110.292222
# 8262   43.5336111 -109.629722
# 8309   41.1400000 -104.819722
# 8645   42.8666667 -106.312500
# 9222   41.5286111 -109.465556
# 9453   44.8994444 -109.150278
# 12511  42.8666667 -106.312500
# 13400  41.1400000 -104.819722
# 14450  44.7538889 -108.756667
# 14899  41.3113889 -105.590556
# 15068  42.0650000 -104.181111
# 15528  41.3113889 -105.590556
# 15696  41.3113889 -105.590556
# 15793  42.8666667 -106.312500
# 15821  42.8666667 -106.312500
# 15843  42.8666667 -106.312500
# 16323  41.3113889 -105.590556
# 17220  44.7538889 -108.756667
# 17711  41.2683333 -110.962500
# 17969  44.2911111 -105.501667
# 18422  41.3113889 -105.590556
# 18719  44.3483333 -106.698333
# 18977  44.7972222 -106.955556
# 22158  43.0063889 -108.881667
# 22608  41.1400000 -104.819722
# 23337  41.5875000 -109.202222
# 23370  41.3113889 -105.590556
# 23978  44.3483333 -106.698333
# 24143  43.0250000 -108.379444
# 25205  44.2911111 -105.501667
# 25224  41.5875000 -109.202222
# 26419  42.8666667 -106.312500

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 ufos_wyoming_df.loc["datetime" == "04/20/1983 24:00"]
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\indexing.py:1201, in _LocIndexer._getitem_axis(self, key, axis)
#    1198         return self.obj.iloc[tuple(indexer)]
#    1200 # fall thru to straight lookup
# -> 1201 self._validate_key(key, axis)
#    1202 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\indexing.py:1011, in _LocIndexer._validate_key(self, key, axis)
#    1001 @doc(_LocationIndexer._validate_key)
#    1002 def _validate_key(self, key, axis: int):
#    1003     # valid for a collection of labels (we check their presence later)
#    1004     # slice of labels (where start-end in labels)
#    1005     # slice of integers (only if in the labels)
#    1006     # boolean not in slice and with boolean index
#    1007     if isinstance(key, bool) and not (
#    1008         is_bool_dtype(self.obj._get_axis(axis))
#    1009         or self.obj._get_axis(axis).dtype.name == "boolean"
#    1010     ):
# -> 1011         raise KeyError(
#    1012             f"{key}: boolean label can not be used without a boolean index"
#    1013         )
#    1015     if isinstance(key, slice) and (
#    1016         isinstance(key.start, bool) or isinstance(key.stop, bool)
#    1017     ):
#    1018         raise TypeError(f"{key}: boolean values can not be used in a slice")
#
# KeyError: 'False: boolean label can not be used without a boolean index'

# %%
ufos_wyoming_df.to_csv("bad_times")

# %%
# Extract year from datetime object

ufos_wyoming_df['year'] = pd.DatetimeIndex(ufos_wyoming_df['datetime']).year

ufos_wyoming_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\PythonData38\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\_libs\tslib.pyx:536, in pandas._libs.tslib.array_to_datetime()
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\dateutil\parser\_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: 4/20/1983 24:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\_libs\tslib.pyx:547, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\PythonData38\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# Input In [50], in <cell line: 3>()
#       1 # Extract year from datetime object
# ----> 3 ufos_wyoming_df['year'] = pd.DatetimeIndex(ufos_wyoming_df['datetime']).year
#       5 ufos_wyoming_df.head()
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\indexes\datetimes.py:327, in DatetimeIndex.__new__(cls, data, freq, tz, normalize, closed, ambiguous, dayfirst, yearfirst, dtype, copy, name)
#     323 # - Cases checked above all return/raise before reaching here - #
#     325 name = maybe_extract_name(name, data, cls)
# --> 327 dtarr = DatetimeArray._from_sequence_not_strict(
#     328     data,
#     329     dtype=dtype,
#     330     copy=copy,
#     331     tz=tz,
#     332     freq=freq,
#     333     dayfirst=dayfirst,
#     334     yearfirst=yearfirst,
#     335     ambiguous=ambiguous,
#     336 )
#     338 subarr = cls._simple_new(dtarr, name=name)
#     339 return subarr
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\arrays\datetimes.py:358, in DatetimeArray._from_sequence_not_strict(cls, data, dtype, copy, tz, freq, dayfirst, yearfirst, ambiguous)
#     354 freq = freq if freq is not lib.no_default else None
#     356 freq, freq_infer = dtl.maybe_infer_freq(freq)
# --> 358 subarr, tz, inferred_freq = _sequence_to_dt64ns(
#     359     data,
#     360     dtype=dtype,
#     361     copy=copy,
#     362     tz=tz,
#     363     dayfirst=dayfirst,
#     364     yearfirst=yearfirst,
#     365     ambiguous=ambiguous,
#     366 )
#     368 freq, freq_infer = dtl.validate_inferred_freq(freq, inferred_freq, freq_infer)
#     369 if explicit_none:
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\arrays\datetimes.py:2082, in _sequence_to_dt64ns(data, dtype, copy, tz, dayfirst, yearfirst, ambiguous, allow_mixed, require_iso8601)
#    2078     data = data.astype(np.int64)
#    2079 else:
#    2080     # data comes back here as either i8 to denote UTC timestamps
#    2081     #  or M8[ns] to denote wall times
# -> 2082     data, inferred_tz = objects_to_datetime64ns(
#    2083         data,
#    2084         dayfirst=dayfirst,
#    2085         yearfirst=yearfirst,
#    2086         allow_object=False,
#    2087         allow_mixed=allow_mixed,
#    2088         require_iso8601=require_iso8601,
#    2089     )
#    2090     if tz and inferred_tz:
#    2091         #  two timezones: convert to intended from base UTC repr
#    2092         if data.dtype == "i8":
#    2093             # GH#42505
#    2094             # by convention, these are _already_ UTC, e.g
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\arrays\datetimes.py:2217, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2215         return values.view("i8"), tz_parsed
#    2216     except (ValueError, TypeError):
# -> 2217         raise err
#    2219 if tz_parsed is not None:
#    2220     # We can take a shortcut since the datetime64 numpy array
#    2221     #  is in UTC
#    2222     # Return i8 values to denote unix timestamps
#    2223     return result.view("i8"), tz_parsed
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\arrays\datetimes.py:2199, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2197 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2198 try:
# -> 2199     result, tz_parsed = tslib.array_to_datetime(
#    2200         data.ravel("K"),
#    2201         errors=errors,
#    2202         utc=utc,
#    2203         dayfirst=dayfirst,
#    2204         yearfirst=yearfirst,
#    2205         require_iso8601=require_iso8601,
#    2206         allow_mixed=allow_mixed,
#    2207     )
#    2208     result = result.reshape(data.shape, order=order)
#    2209 except ValueError as err:
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\_libs\tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\_libs\tslib.pyx:613, in pandas._libs.tslib.array_to_datetime()
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\_libs\tslib.pyx:751, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\_libs\tslib.pyx:742, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~\anaconda3\envs\PythonData38\lib\site-packages\dateutil\parser\_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#     654     ret = self._build_tzaware(ret, res, tzinfos)
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: 4/20/1983 24:00

# %%
# Filter columns of UFO dataframe to include only: Year, City, Duration (seconds), Shape, and Comments

# %% [markdown]
# #### Transform Yellowstone Data

# %%
# Filter columns of Yellowstone dataframe to include only Year and Recreation Visitors

# %% [markdown]
# ### Load

# %% [markdown]
# #### Load UFO data into SQL database

# %% [markdown]
# #### Load Yellowstone data into SQL database
